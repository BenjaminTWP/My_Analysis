# %% [markdown]
# # Part 1: exercise data
# From 2020 I've taken notes about my workouts. Back then my plan wasn't to present the data and perform analysis, primarily I keept track for fun. Thereby the data entries are more scarce and contains less data in each row (more null-values). 2022 and 2023 contains the most entries and 2023 is the most detailed year. Firstly I will quantatively categorize which workout was mostly performed each year. After that the aim is to compare which type of workout consumes the most calories and which workout I usually spend most time at during the workout.
#
# Before doing anything the set will be cleaned, primarily removing an empty column.

# %%
from statistic_theme.workout_per_year import plot_workout_per_year

plot_workout_per_year("tab10")

# %%
from statistic_theme.running import running_regression

running_regression(degree=2, start_year=2020, end_year=2026)

# %%
pip install calplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from statistic_theme.calendar import calendar_activity
from statistic_theme.cycling import cycling_filter

calendar_activity(cycling_filter)

# %%
from statistic_theme.calendar import calendar_activity
from statistic_theme.running import running_filter

calendar_activity(running_filter)

# %%
from statistic_theme.calendar import calendar_activity
from statistic_theme.swimming import crawl_filter

calendar_activity(crawl_filter)

# %%
from statistic_theme.swimming import swimming_speed

swimming_speed(unit="100m/min:sec")
